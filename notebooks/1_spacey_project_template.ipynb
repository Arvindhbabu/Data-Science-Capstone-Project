# %% [markdown]
# # 🚀 Applied Data Science Capstone Project
# ## Space Y: Competing with SpaceX
#
# **Author**: Arvindh Babu V
#
# ---
# ### 📝 Notebook Objectives:
# - Load and explore SpaceX launch data
# - Clean and preprocess the dataset
# - Perform EDA (Exploratory Data Analysis)
# - Build ML models to predict first stage reusability
# - Visualize results and generate business insights

# %%
# 📦 Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import folium
import requests
from bs4 import BeautifulSoup
import sklearn
import warnings
warnings.filterwarnings('ignore')
